# %%
import pkg_resources
from pyspark import pipelines as dp
from helpers import get_logger

# %%
@dp.table(
    name = 'custom_libraries_table',
)

def custom_libraries_table():
    logger = get_logger(__name__)
    logger.info('Starting custom_libraries_table')
    print('Starting custom_libraries_table')
    return (
        spark.read.table('users.andrea_tardif.addresses_sample')
    )
